# %% [markdown]
# <a href="https://colab.research.google.com/github/lopeselio/NLP-weekly/blob/master/Shallow_Parsing_16_Oct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk 
sentence = [("the", "DT"), ("little", "JJ"), ("yellow", "JJ"),("dog", "NN"), ("barked", "VBD"), ("at", "IN"),  ("the", "DT"), ("cat", "NN")]

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"
#Productions from CFG for NP and VP

# %%
cp = nltk.RegexpParser(grammar)
re = cp.parse(sentence)
print(re)
# Out:
# (S
#   (NP the/DT little/JJ yellow/JJ dog/NN)
#   barked/VBD
#   at/IN
#   (NP the/DT cat/NN))

# %%
re.draw()

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)
